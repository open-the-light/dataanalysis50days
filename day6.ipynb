# %%
import numpy as np

# %%
list_str = ["23", "12", "90", "28", "30"]
arr = np.array(list_str, dtype=np.int64)
arr
# Out:
# array([23, 12, 90, 28, 30])

# %%
np.std(arr)
# Out:
# np.float64(27.419700946582186)

# %%
arrf = np.array(list_str, dtype=np.float64)
arrf
# Out:
# array([23., 12., 90., 28., 30.])

# %%
np.sum(arrf[2:])
# Out:
# np.float64(148.0)

# %%
rng = np.random.default_rng(seed = 10)
arrr = rng.integers(100, size=(5, 5))

# %%
print(np.min(arrr))
print(np.max(arrr))
print(np.mean(arrr))
print(np.std(arrr))
# Out:
# 0
# 95
# 49.88
# 29.527370353622754

# %%
first_names = ["John", "Kenny"]
last_names = ["Smith", "Sakula"]
# Out:
# array(['SJohnmJohniJohntJohnh', 'SKennyaKennykKennyuKennylKennya'],
#       dtype='<U31')

# %%
arrc = np.char.join("", [first_names, last_names])

# %%
arrc
# Out:
# array([['John', 'Kenny'],
#        ['Smith', 'Sakula']], dtype='<U6')
