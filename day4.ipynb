# %%
import numpy as np

# %%
rng = np.random.default_rng(seed=10)

# %%
r1 = rng.integers(10, 20, size=(2, 3))
r2 = rng.integers(10, 20, size=(1, 3))
print(r1)
print(r2)
# Out:
# [[15 19 12]
#  [18 10 13]]
# [[17 15 19]]

# %%
r1 + r2
# Out:
# array([[32, 34, 31],
#        [35, 25, 32]])

# %%
np.dot(r1, r2.T)
# Out:
# array([[768],
#        [703]])
